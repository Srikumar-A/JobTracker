# %% [markdown]
# # EMail Classifier
#
# The agenda is to develop a text classification model with better accuracy as compared to the regex performance.

# %% [markdown]
# ## Dataset

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# ## Model
